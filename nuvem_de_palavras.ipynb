# %% [markdown]
# <a href="https://colab.research.google.com/github/Rezsende/nuvem-de-palavras-python/blob/main/nuvem_de_palavras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install wordcloud
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install Pillow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from wordcloud import WordCloud

# %%
piaui_mask = np.array(Image.open("piaui.jpg"))

# %%
words = [
    "Python","Python","Python","Python","Python","Python","Python","Python",
    "Python","Python", "Django", "Flask", "Pyramid", "CherryPy", "TurboGears",
    "Java", "Spring", "Hibernate", "Struts", "Grails", "Play",
    "JavaScript", "React", "Angular", "Vue.js", "Ember.js", "Backbone.js",
    "C++", "Qt", "Boost", "MFC", "WxWidgets", "FLTK",
    "C#", "ASP.NET", "Entity Framework", "MVC", "WPF", "Xamarin",
    "PHP", "Laravel", "Symfony", "CodeIgniter", "CakePHP", "Zend",
    "Ruby", "Ruby on Rails", "Sinatra", "Hanami", "Cuba", "Volt",
    "Swift", "UIKit", "RxSwift", "Alamofire", "SpriteKit", "Metal",
    "Objective-C", "Cocoa", "Core Data", "UIKit", "Cocoa Touch", "OpenStep",
    "SQL", "MySQL", "Oracle", "PostgreSQL", "SQLite", "SQL Server",
    "Perl", "Mojolicious", "Catalyst", "Dancer", "Mason", "CGI.pm",
    "Go", "Gin", "Beego", "Martini", "Revel", "Echo",
    "R", "Shiny", "Dplyr", "Ggplot2", "Tidyr", "Caret",
    "TypeScript", "Angular", "React", "Vue.js", "Ionic", "NestJS",
    "Kotlin", "Spring Boot", "Ktor", "Micronaut", "Vert.x", "Javalin",
    "Visual Basic", "ASP.NET", "Entity Framework", "WPF", "WinForms", "UWP",
    "Scala", "Play", "Akka", "Slick", "Lift", "Spark",
    "Lua", "LÖVE", "Torch", "MoonScript", "OpenResty", "CGILua",
    "Assembly", "NASM", "MASM", "FASM", "TASM", "HLA",
    "Dart", "Flutter", "AngularDart", "Aqueduct", "Angel", "Redstone",
    "Matlab", "Simulink", "Simscape", "Stateflow", "Machine Learning", "Computer Vision",
    "Groovy", "Grails", "Spock", "Gradle", "Ratpack", "Vert.x",
    "Rust", "Rocket", "Actix", "Diesel", "Iron", "Yew",
    "Haskell", "Yesod", "Happstack", "Snap", "Scotty", "Elm",
    "Scheme", "Racket", "Chicken", "Gambit", "Chez", "Larceny",
    "COBOL", "Micro Focus", "IBM COBOL", "OpenCOBOL", "COBOL-IT", "TIBCO",
    "Lisp", "Common Lisp", "Scheme", "Clojure", "Emacs Lisp", "Racket",
    "Prolog", "SWI-Prolog", "GNU Prolog", "SICStus Prolog", "ECLiPSe", "YAP",
    "Node", "Pycharm", "Anaconda", "Jest"
]

# %%
wordcloud = WordCloud(width = 800, height = 800, background_color ='white', contour_color="black", contour_width=3,
                      min_font_size = 10, mask=piaui_mask).generate(' '.join(words))

# wordcloud = WordCloud(width=800, height=800, background_color="white", contour_color="black", contour_width=3).generate(words)

# %%
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud, interpolation='bilinear') 

plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()
